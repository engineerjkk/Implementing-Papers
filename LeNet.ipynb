# %% [markdown]
# <a href="https://colab.research.google.com/github/engineerjkk/implementing-Papers/blob/main/LeNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. import Module

# %%
import tensorflow as tf

# %%
import os

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from tensorflow.keras import datasets

(train_x, train_y), (test_x, test_y) = datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
import cv2

# %%
image = train_x[0]

# %%
# 이미지 shape 확인
image.shape
# Out:
# (28, 28)

# %% [markdown]
# * 차원 수를 확인
# * MNIST의 데이터는 [batch size,height,width,channel]=[60000,28,28,1] 이었다.

# %%
plt.title(image.shape)
plt.imshow(image,'gray')
plt.show()

# %% [markdown]
# # <font color='blue'>2. Input -> C1 Convolutions</font>

# %%
# 차원 수 높이기 
image = image[tf.newaxis, ..., tf.newaxis]

# %%
image.shape
# Out:
# (1, 28, 28, 1)

# %% [markdown]
# filters: layer에서 나갈 때 몇 개의 filter를 만들 것인지 (a.k.a weights, filters, channels)
# kernel_size: filter(Weight)의 사이즈
# strides: 몇 개의 pixel을 skip 하면서 훑어지나갈 것인지 (사이즈에도 영향을 줌)
# padding: zero padding을 만들 것인지. VALID는 Padding이 없고, SAME은 Padding이 있음 (사이즈에도 영향을 줌)
# activation: Activation Function을 만들것인지. 당장 설정 안해도 Layer층을 따로 만들 수 있음

# %% [markdown]
# - tf.keras.layers.Conv2D
# - integer의 경우 모델에 들어가면 에러가나므로 float32로 변경해준다.

# %%
image = tf.cast(image, dtype=tf.float32)

# %%
layer = tf.keras.layers.Conv2D(filters=6,kernel_size=(5,5), strides=(1, 1), padding='SAME')#,activation='tanh')
output = layer(image)

# %%
import numpy as np
np.min(image),np.max(image)
# Out:
# (0.0, 255.0)

# %%
np.min(output),np.max(output)
# Out:
# (-311.0677, 160.24718)

# %%
plt.subplot(1,2,1)
plt.title(image[0,:,:,:].shape)
plt.imshow(image[0,:,:,0],'gray')
plt.subplot(1,2,2)
plt.title(output[0,:,:,:].shape)
plt.imshow(output[0,:,:,0],'gray')
plt.show()

# %% [markdown]
# weight 불러오기
#
# - layer.get_weights()

# %% [markdown]
# 앞에는 weight, 뒤에는 bias이다.

# %%
weight=layer.get_weights()
len(weight)
# Out:
# 2

# %%
weight[0].shape,weight[1].shape
# Out:
# ((5, 5, 1, 6), (6,))

# %%
weight[0].shape
# Out:
# (5, 5, 1, 6)

# %%
plt.imshow(image[0,:,:,0],'gray')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.title(weight[0].shape)
plt.imshow(weight[0][:,:,0,0], 'gray')
plt.subplot(122)
plt.title(output.shape)
plt.imshow(output[0,:,:,0], 'gray')
plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
plt.title(weight[0].shape)
plt.imshow(weight[0][:,:,0,5], 'gray')
plt.subplot(122)
plt.title(output.shape)
plt.imshow(output[0,:,:,5], 'gray')
plt.colorbar()
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# - The popular hyperbolic tangent activation function y ← 1.7159 tanh( 2 3 y) can be approximated by a pair of circular nodes where the activation of the second node y q is fixed at √ 1.9443 and the activation of the first node is calculated accordingly y p ← 1.7159yp/ y 2 p + 1.9443.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
act_output=tf.keras.activations.tanh(output)

# %%
act_output.shape
# Out:
# TensorShape([1, 28, 28, 6])

# %%
np.min(output), np.max(output)
# Out:
# (-311.0677, 160.24718)

# %%
np.min(act_output), np.max(act_output)
# Out:
# (-1.0, 1.0)

# %%
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.hist(act_output.numpy().ravel(), range=[-2,2])
plt.ylim(0, 100)
plt.subplot(132)
plt.title(weight[0].shape)
plt.imshow(weight[0][:,:,0,5], 'gray')
plt.subplot(133)
plt.title(act_output.shape)
plt.imshow(act_output[0,:,:,5], 'gray')
plt.show()

# %% [markdown]
# activation을 tanh를 썼기 때문에 텐서를 받으면 -1~1 사이의 값으로 모두 변환된다.

# %% [markdown]
# # <font color='blue'>3. C1 -> S2 Subsampling</font>

# %% [markdown]
# - tf.keras.layers.AveragePool2D

# %%
layer = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='VALID')
output = layer(act_output)

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1,2,1)
plt.title(output.shape)
plt.imshow(output[0, :, :, 0], 'gray')

# %%
plt.figure(figsize=(15, 5))
plt.subplot(121)
plt.title(output.shape)
plt.imshow(output[0, :, :, 1], 'gray')

# %%
plt.figure(figsize=(15, 5))

plt.title(output.shape)
plt.imshow(output[0, :, :, 2], 'gray')

# %%
plt.figure(figsize=(15, 5))

plt.title(output.shape)
plt.imshow(output[0, :, :, 3], 'gray')

# %%
plt.figure(figsize=(15, 5))
plt.title(output.shape)
plt.imshow(output[0, :, :, 4], 'gray')

# %%
plt.figure(figsize=(15, 5))
plt.title(output.shape)
plt.imshow(output[0, :, :, 5], 'gray')

# %% [markdown]
# # <font color='blue'>4. S2 -> C3 Convoltions</font>

# %% [markdown]
# C3filter0 = (S2filter0 matrix +S2filter1 matrix +S2filter2 matrix) -> tanh

# %%
def convolution(m,f,s=1): 
  import numpy as np 
  mx,my=np.shape(m) 
  fx,fy=np.shape(f) 
  if (mx-fx)%s==0 and (my-fy)%s==0: 
    print('convolution 연산 가능') 
  else: 
    print('convolution 연산 불가능') 
    print('(mx-fx)%s=',(mx-fx)%s) 
    print('(my-fy)%s=',(my-fy)%s) 
    return 
  o=[] 
  for i in range(0,mx-fx+1,s): 
    for j in range(0,my-fy+1,s): 
      o.append((m[i:i+fx,j:j+fy]*f).sum())
  ow=int((mx-fx)/s)+1 
  oh=int((my-fy)/s)+1 
  #print('ouptput 크기=(%s,%s)'%(ow,oh)) 
  o=np.array(o).reshape(oh,ow) 
  return o

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D

# %%
output.shape
# Out:
# TensorShape([1, 14, 14, 6])

# %%
for i in range(0,6):
  globals()['S2filter{}'.format(i)]=convolution(output[0, :, :, i].numpy(),weight[0][:,:,0,i],s=1)
# Out:
# convolution 연산 가능
# convolution 연산 가능
# convolution 연산 가능
# convolution 연산 가능
# convolution 연산 가능
# convolution 연산 가능

# %%
plt.title(S2filter0.shape)
plt.imshow(S2filter0, 'gray')

# %%
plt.title(S2filter1.shape)
plt.imshow(S2filter1, 'gray')

# %%
plt.title(S2filter2.shape)
plt.imshow(S2filter2, 'gray')

# %%
plt.title(S2filter3.shape)
plt.imshow(S2filter3, 'gray')

# %%
plt.title(S2filter4.shape)
plt.imshow(S2filter4, 'gray')

# %%
plt.title(S2filter5.shape)
plt.imshow(S2filter5, 'gray')

# %% [markdown]
# tanh

# %%
def tanh(x):
    return (np.exp(x/2)-np.exp(-x/2))/(np.exp(x/2)+np.exp(-x/2))

# %%
x = np.linspace(-10,10,100)
y = []
for dig in x:
    y.append(tanh(dig))
plt.plot(x,np.reshape(y,(100,)))
plt.show()

# %%
C3filter0 = tanh(S2filter0 +S2filter1+S2filter2)
C3filter1 = tanh(S2filter1 +S2filter2+S2filter3)
C3filter2 = tanh(S2filter2 +S2filter3+S2filter4)
C3filter3 = tanh(S2filter3 +S2filter4+S2filter5)
C3filter4 = tanh(S2filter0 +S2filter4+S2filter5)
C3filter5 = tanh(S2filter0 +S2filter1+S2filter5)
C3filter6 = tanh(S2filter0 +S2filter1+S2filter2+S2filter3)
C3filter7 = tanh(S2filter1 +S2filter2+S2filter3+S2filter4)
C3filter8 = tanh(S2filter2 +S2filter3+S2filter4+S2filter5)
C3filter9 = tanh(S2filter0 +S2filter3+S2filter4+S2filter5)
C3filter10 = tanh(S2filter0 +S2filter1+S2filter4+S2filter5)
C3filter11 = tanh(S2filter0 +S2filter1+S2filter2+S2filter5)
C3filter12= tanh(S2filter0 +S2filter1+S2filter3+S2filter4)
C3filter13 = tanh(S2filter1 +S2filter2+S2filter4+S2filter5)
C3filter14 = tanh(S2filter0 +S2filter2+S2filter3+S2filter5)
C3filter15 = tanh(S2filter0 +S2filter1+S2filter2+S2filter3+S2filter4+S2filter5)

# %%
plt.title('C3 : feature 0')
plt.imshow(C3filter0, 'gray')

# %%
plt.title('C3 : feature 1')
plt.imshow(C3filter1, 'gray')

# %%
plt.title('C3 : feature 2')
plt.imshow(C3filter2, 'gray')

# %%
plt.title('C3 : feature 3')
plt.imshow(C3filter3, 'gray')

# %%
plt.title('C3 : feature 4')
plt.imshow(C3filter4, 'gray')

# %%
plt.title('C3 : feature 5')
plt.imshow(C3filter5, 'gray')

# %%
plt.title('C3 : feature 6')
plt.imshow(C3filter6, 'gray')

# %%
plt.title('C3 : feature 7')
plt.imshow(C3filter7, 'gray')

# %%
plt.title('C3 : feature 8')
plt.imshow(C3filter8, 'gray')

# %%
plt.title('C3 : feature 9')
plt.imshow(C3filter9, 'gray')

# %%
plt.title('C3 : feature 10')
plt.imshow(C3filter10, 'gray')

# %%
plt.title('C3 : feature 11')
plt.imshow(C3filter11, 'gray')

# %%
plt.title('C3 : feature 12')
plt.imshow(C3filter12, 'gray')

# %%
plt.title('C3 : feature 13')
plt.imshow(C3filter13, 'gray')

# %%
plt.title('C3 : feature 14')
plt.imshow(C3filter14, 'gray')

# %%
plt.title('C3 : feature 15')
plt.imshow(C3filter15, 'gray')

# %% [markdown]
# 차원 수를 맞춰주기 위함

# %%
for i in range(0,16):
  globals()['C3filter{}'.format(i)]=globals()['C3filter{}'.format(i)][tf.newaxis, ..., tf.newaxis]

# %%
featureMap=np.concatenate((C3filter0, C3filter1,C3filter2,C3filter3,C3filter4,C3filter5,C3filter6,C3filter7,C3filter8,C3filter9,C3filter10,C3filter11,C3filter12,C3filter13,C3filter14,C3filter15), axis=3)

# %%
featureMap.shape
# Out:
# (1, 10, 10, 16)

# %%
plt.figure(figsize=(15, 5))
plt.title(featureMap.shape)
plt.imshow(featureMap[0, :, :, 0], 'gray')
plt.colorbar()
plt.show()

# %% [markdown]
# 따라서 각 필터연산된 feature map을 모두 연산한 뒤에 다음레이어에 들어갈때 그 matrix에 activation function을 각 픽셀마다 곱해 연산해주는 것이다.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <font color='blue'>5. C3 -> S4 : Subsampling</font>

# %%
layer = tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2), padding='VALID')
output = layer(featureMap)

# %%
plt.figure(figsize=(15, 5))
#plt.title(output.shape)
plt.axis('off')
plt.imshow(output[0, :, :, 7], 'gray')
plt.show()

# %% [markdown]
# # 6. Classifier (Fully Connected Layer)

# %% [markdown]
# - tf.keras.layers.Flatten()

# %%
layer = tf.keras.layers.Flatten()
output = layer(output)

# %%
output.shape
# Out:
# TensorShape([1, 400])

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
plt.hist(output.numpy().ravel())
plt.subplot(212)
plt.imshow(output[:,:400],'gray')
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(output[:,:400],'gray')
plt.show()

# %% [markdown]
# 내보낼 유닛 개수를 120개로 설정하고 이 120개와 S4의 feature map 모두 연결한다는 뜻이된다.

# %%
layer = tf.keras.layers.Dense(120, activation='tanh')
output = layer(output)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
plt.hist(output.numpy().ravel())
plt.subplot(212)
plt.imshow(output[:,:120],'gray')
plt.show()

# %%
layer = tf.keras.layers.Dense(84, activation='tanh')
output = layer(output)

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
plt.hist(output.numpy().ravel())
plt.subplot(212)
plt.imshow(output[:,:84],'gray')
plt.show()

# %%
layer = tf.keras.layers.Dense(10, activation='softmax')
output = layer(output)

# %% [markdown]
# <font color='red'>RBF가 아닌 softmax 주의</font>

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
plt.hist(output.numpy().ravel())
plt.subplot(212)
plt.imshow(output[:,:10],'gray')
plt.show()

# %% [markdown]
# 가장 확률 높은값 찾기

# %%
output
# Out:
# <tf.Tensor: shape=(1, 10), dtype=float32, numpy=
# array([[0.13398242, 0.07399851, 0.04276639, 0.06752071, 0.07273757,
#         0.19405209, 0.06658181, 0.06927752, 0.16609399, 0.11298903]],
#       dtype=float32)>

# %%
result=np.argmax(output)
result
# Out:
# 5

# %% [markdown]
# # 7. Build Model

# %%
from tensorflow.keras import layers

# %%
input_shape = (28, 28, 1)

# %%
inputs = layers.Input(input_shape)
#32는 필터개수 
#feature extraction이며, 여기서는 전부 연결헀고 끝에 Dropout을 설정해줬다.
net = layers.Conv2D(6, (5, 5), padding='SAME')(inputs)
net = layers.Activation('tanh')(net)
net = layers.AveragePooling2D(pool_size=(2, 2))(net)
net = layers.Dropout(0.5)(net) #LeNet Table 묘사
net = layers.Conv2D(16, (5, 5), padding='VALID')(net)
net = layers.Activation('tanh')(net)
net = layers.AveragePooling2D(pool_size=(2, 2))(net)

net = layers.Flatten()(net)
net = layers.Dense(120)(net)
net = layers.Activation('tanh')(net)

net = layers.Dense(84)(net)
net = layers.Activation('tanh')(net)

net = layers.Dense(10)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs=inputs, outputs=net, name='CVandAR')

# %%
model.summary()
# Out:
# Model: "CVandAR"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 6)         156
#
#  activation (Activation)     (None, 28, 28, 6)         0
#
#  average_pooling2d_2 (Averag  (None, 14, 14, 6)        0
#  ePooling2D)
#
#  dropout (Dropout)           (None, 14, 14, 6)         0
#
#  conv2d_2 (Conv2D)           (None, 10, 10, 16)        2416
#
#  activation_1 (Activation)   (None, 10, 10, 16)        0
#
#  average_pooling2d_3 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 400)               0
#
#  dense_3 (Dense)             (None, 120)               48120
#
#  activation_2 (Activation)   (None, 120)               0
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  activation_3 (Activation)   (None, 84)                0
#
#  dense_5 (Dense)             (None, 10)                850
#
#  activation_4 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  # 8. Training

# %%
epochs = 100
batch_size = 200

hist = model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(test_x, test_y))
val_loss = hist.history['val_loss']
val_acc = hist.history['val_acc']

font_name = matplotlib.font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
matplotlib.rc('font', family=font_name)

fig = plt.figure()
ax_acc = fig.add_subplot(111)

ax_acc.plot(range(epochs), val_acc, label='정확도(%)', color='darkred')
plt.text(3, 14.7, "<----------------정확도(%)", verticalalignment='top', horizontalalignment='right')
plt.xlabel('epochs')
ax_acc.grid(linestyle='--', color='lavender')

plt.show()
# Out:
# Epoch 1/100
# 300/300 [==============================] - 3s 8ms/step - loss: 0.4583 - accuracy: 0.8661 - val_loss: 0.1831 - val_accuracy: 0.9459
# Epoch 2/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.1817 - accuracy: 0.9456 - val_loss: 0.1176 - val_accuracy: 0.9638
# Epoch 3/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.1272 - accuracy: 0.9608 - val_loss: 0.0920 - val_accuracy: 0.9705
# Epoch 4/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.0992 - accuracy: 0.9691 - val_loss: 0.0763 - val_accuracy: 0.9766
# Epoch 5/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.0866 - accuracy: 0.9720 - val_loss: 0.0655 - val_accuracy: 0.9807
# Epoch 6/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.0721 - accuracy: 0.9775 - val_loss: 0.0596 - val_accuracy: 0.9818
# Epoch 7/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.0642 - accuracy: 0.9797 - val_loss: 0.0536 - val_accuracy: 0.9839
# Epoch 8/100
# 300/300 [==============================] - 2s 7ms/step - loss: 0.
#   0.053434107452631,
#   0.05358835309743881,
#   0.05190363898873329,
#   0.04980282858014107,
#   0.05034339055418968,
#   0.05150362104177475,
#   0.052340067923069,
#   0.05654587224125862,
#   0.055198993533849716,
#   0.0577886663377285,
#   0.05495992302894592,
#   0.056755781173706055,
#   0.05463867634534836,
#   0.0488695353269577,
#   0.05108480155467987,
#   0.04848071187734604,
#   0.049451421946287155,
#   0.05213608965277672,
#   0.04948054254055023,
#   0.05016462504863739,
#   0.05122089385986328,
#   0.05329819768667221,
#   0.05162439122796059,
#   0.05549147352576256,
#   0.05154075846076012,
#   0.05407896265387535,
#   0.05464072898030281,
#   0.05329461768269539,
#   0.05473902076482773,
#   0.05618909373879433,
#   0.053370341658592224,
#   0.05367358401417732,
#   0.05054958164691925,
#   0.053316630423069,
#   0.05756061524152756,
#   0.05588411167263985,
#   0.0571410208940506,
#   0.05670298635959625,
#   0.05537277087569237,
#   0.05220474302768707,
#   0.04799104481935501,
#   0.05780080705881119,
#   0.05384410545229912,
#   0.05588752403855324,
#   0.05273570492863655,
#   0.052714671939611435,
#   0.061696168035268784]}

# %%
## Plot losses
plt.plot(hist.history['loss'],'-b',label='loss')
plt.plot(hist.history['val_loss'],'r--',label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
## Plot Accuracy
plt.plot(hist.history['accuracy'],'b-',label='acc')
plt.plot(hist.history['val_accuracy'],'r--',label='val_acc')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
model.evaluate(test_x, test_y, batch_size=batch_size)
# Out:
# 50/50 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9857
# [0.061696168035268784, 0.9857000112533569]

# %% [markdown]
# # 9. Appendix

# %% [markdown]
# Optimizer and Traning

# %%
import tensorflow as tf
from tensorflow.keras import layers

from tensorflow.keras import datasets

# %%
input_shape = (28, 28, 1)
num_classes = 10

learning_rate = 0.001

# %%
# Model is the full model w/o custom layers
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
(train_x, train_y), (test_x, test_y) = datasets.mnist.load_data()

# %%
train_x = train_x[..., tf.newaxis]
test_x = test_x[..., tf.newaxis]

train_x = train_x / 255.
test_x = test_x / 255.

# %% [markdown]
# DropOut

# %% [markdown]
# - tf.keras.layers.Dropout

# %%
layer = tf.keras.layers.Dropout(0.7)
output = layer(output)

# %%
output.shape
# Out:
# TensorShape([1, 10])

# %%
plt.figure(figsize=(10, 5))
plt.subplot(211)
plt.hist(output.numpy().ravel())
plt.subplot(212)
plt.imshow(output[:,:100])
plt.show()

# %% [markdown]
# 다른 CNN 모델 학습

# %%
inputs = layers.Input(input_shape)
net = layers.Conv2D(32, (3, 3), padding='SAME')(inputs)
net = layers.Activation('relu')(net)
net = layers.Conv2D(32, (3, 3), padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPooling2D(pool_size=(2, 2))(net)
net = layers.Dropout(0.5)(net)

net = layers.Conv2D(64, (3, 3), padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.Conv2D(64, (3, 3), padding='SAME')(net)
net = layers.Activation('relu')(net)
net = layers.MaxPooling2D(pool_size=(2, 2))(net)
net = layers.Dropout(0.5)(net)

net = layers.Flatten()(net)
net = layers.Dense(512)(net)
net = layers.Activation('relu')(net)
net = layers.Dropout(0.5)(net)
net = layers.Dense(num_classes)(net)
net = layers.Activation('softmax')(net)

model = tf.keras.Model(inputs=inputs, outputs=net, name='Basic_CNN')

# %%
# Model is the full model w/o custom layers
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
(train_x, train_y), (test_x, test_y) = datasets.mnist.load_data()

# %%
train_x = train_x[..., tf.newaxis]
test_x = test_x[..., tf.newaxis]

train_x = train_x / 255.
test_x = test_x / 255.

# %%
epochs = 100
batch_size = 200

hist = model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(test_x, test_y))
val_loss = hist.history['val_loss']
val_acc = hist.history['val_acc']

font_name = matplotlib.font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
matplotlib.rc('font', family=font_name)

fig = plt.figure()
ax_acc = fig.add_subplot(111)

ax_acc.plot(range(epochs), val_acc, label='정확도(%)', color='darkred')
plt.text(3, 14.7, "<----------------정확도(%)", verticalalignment='top', horizontalalignment='right')
plt.xlabel('epochs')
ax_acc.grid(linestyle='--', color='lavender')

plt.show()
# Out:
# Epoch 1/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.3049 - accuracy: 0.9007 - val_loss: 0.0479 - val_accuracy: 0.9846
# Epoch 2/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0884 - accuracy: 0.9728 - val_loss: 0.0303 - val_accuracy: 0.9889
# Epoch 3/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0676 - accuracy: 0.9797 - val_loss: 0.0264 - val_accuracy: 0.9908
# Epoch 4/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0556 - accuracy: 0.9830 - val_loss: 0.0235 - val_accuracy: 0.9926
# Epoch 5/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0487 - accuracy: 0.9849 - val_loss: 0.0203 - val_accuracy: 0.9930
# Epoch 6/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0410 - accuracy: 0.9874 - val_loss: 0.0202 - val_accuracy: 0.9929
# Epoch 7/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0399 - accuracy: 0.9878 - val_loss: 0.0197 - val_accuracy: 0.9933
# Epoch 8/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0352 - accuracy: 0.9893 - val_loss: 0.0181 - val_accuracy: 0.9938
# Epoch 9/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0170 - val_accuracy: 0.9950
# Epoch 10/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0281 - accuracy: 0.9908 - val_loss: 0.0151 - val_accuracy: 0.9949
# Epoch 11/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0308 - accuracy: 0.9908 - val_loss: 0.0160 - val_accuracy: 0.9946
# Epoch 12/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.0147 - val_accuracy: 0.9951
# Epoch 13/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.0166 - val_accuracy: 0.9951
# Epoch 14/100
# 300/300 [==============================] - 9s 28ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 0.0155 - val_accuracy: 0.9952
# Epoch 15/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.
100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0185 - val_accuracy: 0.9958
# Epoch 89/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0198 - val_accuracy: 0.9954
# Epoch 90/100
# 300/300 [==============================] - 9s 28ms/step - loss: 0.0089 - accuracy: 0.9969 - val_loss: 0.0200 - val_accuracy: 0.9956
# Epoch 91/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0152 - val_accuracy: 0.9961
# Epoch 92/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.0173 - val_accuracy: 0.9959
# Epoch 93/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0080 - accuracy: 0.9975 - val_loss: 0.0167 - val_accuracy: 0.9962
# Epoch 94/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0199 - val_accuracy: 0.9958
# Epoch 95/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0178 - val_accuracy: 0.9953
# Epoch 96/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0182 - val_accuracy: 0.9956
# Epoch 97/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0094 - accuracy: 0.9970 - val_loss: 0.0191 - val_accuracy: 0.9957
# Epoch 98/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0093 - accuracy: 0.9973 - val_loss: 0.0185 - val_accuracy: 0.9953
# Epoch 99/100
# 300/300 [==============================] - 9s 29ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0168 - val_accuracy: 0.9958
# Epoch 100/100
# 300/300 [==============================] - 8s 28ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.0191 - val_accuracy: 0.9955
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-252-1f24fdda8387> in <module>()
#       4 hist = model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, validation_data=(test_x, test_y))
#       5 val_loss = hist.history['val_loss']
# ----> 6 val_acc = hist.history['val_acc']
#       7
#       8 font_name = matplotlib.font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
#
# KeyError: 'val_acc'

# %%
hist.history
# Out:
# {'accuracy': [0.9006833434104919,
#   0.9728333353996277,
#   0.9796500205993652,
#   0.9829999804496765,
#   0.9848666787147522,
#   0.9874333143234253,
#   0.9878000020980835,
#   0.9893333315849304,
#   0.9897333383560181,
#   0.9908166527748108,
#   0.9907833337783813,
#   0.9912833571434021,
#   0.9916499853134155,
#   0.9923999905586243,
#   0.9923499822616577,
#   0.9929500222206116,
#   0.9926499724388123,
#   0.9931666851043701,
#   0.9930333495140076,
#   0.9936333298683167,
#   0.9943000078201294,
#   0.9942166805267334,
#   0.9940666556358337,
#   0.994533360004425,
#   0.9943000078201294,
#   0.9947999715805054,
#   0.9947666525840759,
#   0.9944999814033508,
#   0.9951666593551636,
#   0.9954666495323181,
#   0.9949666857719421,
#   0.9941999912261963,
#   0.9956333041191101,
#   0.9956499934196472,
#   0.9953833222389221,
#   0.9955833554267883,
#   0.9955833554267883,
#   0.9951000213623047,
#   0.9962833523750305,
#   0.9959166646003723,
#   0.9960500001907349,
#   0.9958500266075134,
#   0.9961000084877014,
#   0.996233344078064,
#   0.9959333539009094,
#   0.9962666630744934,
#   0.9955000281333923],
#  'val_loss': [0.047856975346803665,
#   0.030308200046420097,
#   0.0264438483864069,
#   0.023508809506893158,
#   0.02026204764842987,
#   0.020181216299533844,
#   0.019684765487909317,
#   0.018074525520205498,
#   0.016971677541732788,
#   0.015136785805225372,
#   0.01604863815009594,
#   0.014736694283783436,
#   0.016584625467658043,
#   0.015490690246224403,
#   0.015154496766626835,
#   0.014503620564937592,
#   0.016607660800218582,
#   0.018582791090011597,
#   0.013734324835240841,
#   0.014703107997775078,
#   0.017571471631526947,
#   0.01611326076090336,
#   0.013585464097559452,
#   0.013375965878367424,
#   0.016277341172099113,
#   0.01385030522942543,
#   0.014649697579443455,
#   0.014961758628487587,
#   0.014077788218855858,
#   0.015882063657045364,
#   0.01303101610392332,
#   0.014148449525237083,
#   0.014460565522313118,
#   0.013205801136791706,
#   0.016048643738031387,
#   0.016330022364854813,
#   0.01567986235022545,
#   0.0138110825791955,
#   0.014327923767268658,
#   0.012761185877025127,
#   0.014547061175107956,
#   0.01770552434027195,
#   0.015138772316277027,
#   0.017171746119856834,
#   0.013619508594274521,
#   0.016116656363010406,
#   0.016404706984758377,
#   0.015133040025830269,
#   0.0181569941341877,
#   0.013709977269172668,
#   0.015050486661493778,
#   0.017741059884428978,
#   0.01699734479188919,
#   0.01504313200712204,
#   0.017660660669207573,
#   0.019145093858242035,
#   0.016997892409563065,
#   0.013438270427286625,
#   0.017515821382403374,
#   0.01837528869509697,
#   0.016872327774763107,
#   0.01674583926796913,
#   0.018896130844950676,
#   0.016349628567695618,
#   0.01682211458683014,
#   0.016284067183732986,
#   0.019434353336691856,
#   0.018234139308333397,
#   0.01915188506245613,
#   0.017337510362267494,
#   0.015899179503321648,
#   0.01918981224298477,
#   0.015444152988493443,
#   0.015248781070113182,
#   0.017251156270503998,
#   0.018668947741389275,
#   0.01747141405940056,
#   0.015091432258486748,
#   0.01694776676595211,
#   0.01804768294095993,
#   0.01933070831000805,
#   0.018010331317782402,
#   0.01914355345070362,
#   0.018342867493629456,
#   0.01617189310491085,
#   0.017407521605491638,
#   0.01810980960726738,
#   0.018509861081838608,
#   0.019772104918956757,
#   0.020044201985001564,
#   0.01515095867216587,
#   0.0173268411308527,
#   0.01665983721613884,
#   0.019948873668909073,
#   0.017796745523810387,
#   0.018216727301478386,
#   0.019088149070739746,
#   0.018549147993326187,
#   0.01675981469452381,
#   0.019106078892946243]}

# %%
## Plot losses
plt.plot(hist.history['loss'],'-b',label='loss')
plt.plot(hist.history['val_loss'],'r--',label='val_loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
## Plot Accuracy
plt.plot(hist.history['accuracy'],'b-',label='acc')
plt.plot(hist.history['val_accuracy'],'r--',label='val_acc')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
model.evaluate(test_x, test_y, batch_size=batch_size)
# Out:
# 50/50 [==============================] - 1s 11ms/step - loss: 0.0191 - accuracy: 0.9955
# [0.019106078892946243, 0.9955000281333923]
